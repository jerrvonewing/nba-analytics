# %%
# import get_data notebook
# %run get_data.ipynb
# Out:
# zsh:1: command not found: playwright

# %%
# Scraping the box scores for each season
for season in SEASONS:
    await scrape_season(season)
# Out:
# Timeout error on https://www.basketball-reference.com/leagues/NBA_2016_games.html
# Timeout error on https://www.basketball-reference.com/leagues/NBA_2016_games.html
# 2015-16 NBA Schedule | Basketball-Reference.com
# 2015-16 NBA Schedule | Basketball-Reference.com
# Timeout error on https://basketball-reference.com/leagues/NBA_2016_games-november.html
# 2015-16 NBA Schedule | Basketball-Reference.com
# Timeout error on https://basketball-reference.com/leagues/NBA_2016_games-december.html
# Timeout error on https://basketball-reference.com/leagues/NBA_2016_games-december.html
# Timeout error on https://basketball-reference.com/leagues/NBA_2016_games-december.html
# 2015-16 NBA Schedule | Basketball-Reference.com
# Timeout error on https://basketball-reference.com/leagues/NBA_2016_games-january.html
# 2015-16 NBA Schedule | Basketball-Reference.com
# Timeout error on https://basketball-reference.com/leagues/NBA_2016_games-february.html
# ...
